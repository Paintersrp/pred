# %%
import pandas as pd
import scripts.const as const
import scripts.utils as utils
import scripts.transform as transform
import scripts.handler as handler
import scripts.updater as updater
from scripts.predictor import DailyPredictor, Predictor
from scripts.scraper import Scraper
from scripts.simulator import Simulator, SimPredictor, SimRandom
import numpy as np
import json

SimRandom = SimRandom(bet_value = 100, win_rate = 0.66, num_games = 1200)
SimRandom.calculate()
data = SimRandom.return_data()
data
# Out:
#            Date    Time                    Away A-Pts                   Home  \
# 0    2015-02-06   7:30p          Denver Nuggets    88        Detroit Pistons
# 1    2021-04-12   7:30p      Philadelphia 76ers   113       Dallas Mavericks
# 2    2013-03-08  10:30p         Houston Rockets    94  Golden State Warriors
# 3    2018-03-04   3:30p            Phoenix Suns   112          Atlanta Hawks
# 4    2009-03-27   7:30p     New Orleans Hornets    93        New York Knicks
# ...         ...     ...                     ...   ...                    ...
# 1195 2016-12-21   7:30p  Minnesota Timberwolves    92          Atlanta Hawks
# 1196 2013-05-11   8:00p         New York Knicks    71         Indiana Pacers
# 1197 2021-04-02  10:00p      Los Angeles Lakers   115       Sacramento Kings
# 1198 2011-01-01   9:00p       Memphis Grizzlies    92              Utah Jazz
# 1199 2019-04-21   7:00p         Toronto Raptors   107          Orlando Magic
#
# ...

# %%
SimRandom.return_totals()
# Out:
# (36652.391824835795, -41400.0, -4747.608175164205, -0.8853234740298501)

# %%
SimRandom.reroll()
SimRandom.calculate()
SimRandom.return_totals()
# Out:
# (38365.32951668899, -39600.0, -1234.6704833110125, -0.9688214524416411)
