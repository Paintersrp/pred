# %% [markdown]
# Completely randomized betting simulator, no logic is applied to which games are bet on.

# %%
import pandas as pd
from scripts.simulator import SimRandom

SimRandom = SimRandom(bet_value = 100, win_rate = 0.66, num_games = 1200)
SimRandom.calculate()
SimRandom.return_data()
# Out:
#            Date    Time                   Away A-Pts                    Home  \
# 0    2009-10-28  10:30p           Phoenix Suns   109    Los Angeles Clippers
# 1    2010-03-22   8:00p      San Antonio Spurs    99   Oklahoma City Thunder
# 2    2010-01-26  10:00p  Golden State Warriors    96        Sacramento Kings
# 3    2007-11-09   8:00p         Denver Nuggets   118      Washington Wizards
# 4    2021-01-18   3:00p      San Antonio Spurs   125  Portland Trail Blazers
# ...         ...     ...                    ...   ...                     ...
# 1195 2015-03-10   8:30p        Toronto Raptors   107       San Antonio Spurs
# 1196 2007-12-18   7:30p       Sacramento Kings   106         New Jersey Nets
# 1197 2017-12-15   7:00p  Oklahoma City Thunder   119      Philadelphia 76ers
# 1198 2009-12-01   9:00p  Golden State Warriors   107          Denver Nuggets
# 1199 2019-04-07   7:30p     Washington Wizards   110         New York Knicks
#
# ...

# %%
SimRandom.return_totals()
# Out:
# (39028.6769078001, -39100.0, -71.32309219989838, -0.9981758799948875)

# %%
SimRandom.reroll()
SimRandom.calculate()
SimRandom.return_totals()
# Out:
# (39485.504805657416, -35800.0, 3685.504805657416, -1.1029470616105423)

# %%
SimRandom.return_data()
# Out:
#            Date    Time                    Away A-Pts                    Home  \
# 0    2011-03-21   7:00p           Orlando Magic    97     Cleveland Cavaliers
# 1    2019-03-27   8:00p  Portland Trail Blazers   118           Chicago Bulls
# 2    2012-12-10  10:00p         Toronto Raptors    74  Portland Trail Blazers
# 3    2016-02-06   5:00p  Portland Trail Blazers    96         Houston Rockets
# 4    2015-12-22   7:00p       Memphis Grizzlies   104      Philadelphia 76ers
# ...         ...     ...                     ...   ...                     ...
# 1195 2016-03-14  10:30p     Cleveland Cavaliers    85               Utah Jazz
# 1196 2008-02-02   8:30p         Houston Rockets    91         Milwaukee Bucks
# 1197 2015-01-13   9:00p   Golden State Warriors   116               Utah Jazz
# 1198 2022-04-23   4:30p        Dallas Mavericks    99               Utah Jazz
# 1199 2017-10-28   9:00p      Los Angeles Lakers    81               Utah Jazz
#
# ...

# %%
SimRandom.worst_losses()
# Out:
#         Date    Time                   Away A-Pts                    Home  \
# 0 2008-04-06   3:30p       Dallas Mavericks   105            Phoenix Suns
# 1 2016-01-20   8:00p        Detroit Pistons   123         Houston Rockets
# 2 2013-03-29  10:00p              Utah Jazz   105  Portland Trail Blazers
# 3 2015-03-02   7:00p        Toronto Raptors   114      Philadelphia 76ers
# 4 2018-05-06   3:30p  Golden State Warriors   118    New Orleans Pelicans
#
#    H-Pts OT SeasonID   MOV Spread    O/U    A_ML  ML_Payout    H_ML  \
# 0     98     2007-08  -7.0   15.5    211  2000.0     2000.0 -3000.0
# 1    114     2015-16  -9.0   15.5  216.5  1910.0     1910.0 -7123.0
# 2     95     2012-13 -10.0   14.5  203.5  1520.0     1520.0 -3320.0
# 3    103     2014-15 -11.0     15  211.5  1410.0     1410.0 -3010.0
# 4     92     2017-18 -26.0     14    222  1300.0     1300.0 -3500.0
#
#    Bet_Status  Value
# 0           0 -100.0
# 1           0 -100.0
# 2           0 -100.0
# ...
